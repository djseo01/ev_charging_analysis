# %%
import pandas as pd
import googlemaps

# 데이터 불러오기
df = pd.read_csv('Electric vehicle charging station location.csv')

# '충전소명'을 기준으로 행을 그룹화하고, 각 그룹의 첫 번째 행만 남기기
filtered_df = df.groupby('충전소명').first().reset_index()

# '충전기 댓수' 열 추가
filtered_df['충전기 댓수'] = df.groupby('충전소명').size().values

# 필요한 열만 선택하여 새로운 데이터프레임 생성
selected_columns = ['주소', '충전소명', '충전기 댓수']  # 필요한 열 이름들
new_df = filtered_df[selected_columns]

# 데이터 샘플링을 통해 10 등분
num_portions = 10
portion_size = len(new_df) // num_portions

# Google Maps Geocoding API 키 설정
api_key = 'AIzaSyA8TPi-Zr3JQ-pnTUWddKikyd7EZ8HTrFU'  # 'your_google_maps_api_key'에 본인의 API 키를 입력하세요.
gmaps = googlemaps.Client(key=api_key)

def get_lat_lon(address):
    try:
        # Geocoding API를 사용하여 주소를 위도와 경도로 변환
        geocode_result = gmaps.geocode(address)
        
        # 결과에서 위도와 경도 추출
        location = geocode_result[0]['geometry']['location']
        return location['lat'], location['lng']
    except:
        return None, None

# 각 부분에 대해 주소 열에서 위도와 경도를 추출하여 새로운 열로 추가
for i in range(num_portions):
    portion = new_df.sample(n=portion_size, random_state=i)
    
    portion['위도'], portion['경도'] = zip(*portion['주소'].apply(get_lat_lon))

    # 결과를 새로운 CSV 파일로 저장
    file_name = f'Electric vehicle charging station location_위도경도_{i + 1}.csv'
    portion.to_csv(file_name, index=False)

# %%
import pandas as pd
import googlemaps

# 데이터 불러오기
df = pd.read_csv('Electric vehicle charging station location.csv')

# '충전소명'을 기준으로 행을 그룹화하고, 각 그룹의 첫 번째 행만 남기기
filtered_df = df.groupby('충전소명').first().reset_index()

# '충전기 댓수' 열 추가
filtered_df['충전기 댓수'] = df.groupby('충전소명').size().values

# 필요한 열만 선택하여 새로운 데이터프레임 생성
selected_columns = ['주소', '충전소명', '충전기 댓수']  # 필요한 열 이름들
new_df = filtered_df[selected_columns]

# %%
new_df
# Out:
#                                주소               충전소명  충전기 댓수
# 0               부산광역시 사하구 사하로 182  (IDS)아델하임 입주자대표회의       3
# 1           강원도 고성군 거진읍 거진리 22-93      (구)거진수산센터 주차장       2
# 2      제주특별자치도 서귀포시 천제연로 147(중문동)          (구)중문보건지소       1
# 3           인천광역시 남동구 청능대로718번길 7      (급속)논현풍림-3주차장       1
# 4                 대구광역시 중구 서성로 99       (급속)대구역센트럴자이       1
# ...                           ...                ...     ...
# 49897     서울특별시 용산구 유엔빌리지길 200-16           힐탑트레져아파트       4
# 49898       전라북도 고창군 흥덕면 잿말길 87-8             힐튼파크모텔       1
# 49899      경기도 화성시 팔탄면 3.1만세로 828                힐파크       2
# 49900         경기도 안성시 일죽면 사실로 339             힐하얏트모텔       1
# 49901         제주특별자치도 제주시 은수길 6-4               힐하우스       1
#
# [49902 rows x 3 columns]

# %%
api_key = 'AIzaSyA8TPi-Zr3JQ-pnTUWddKikyd7EZ8HTrFU'  # 자신의 Google Maps API 키로 교체
gmaps = googlemaps.Client(key=api_key)

def get_lat_lon(address):
    try:
        # Geocoding API를 사용하여 주소를 위도와 경도로 변환
        geocode_result = gmaps.geocode(address)
        
        # 결과에서 위도와 경도 추출
        location = geocode_result[0]['geometry']['location']
        return location['lat'], location['lng']
    except:
        return None, None

# '주소' 열에서 위도와 경도를 추출하여 새로운 열로 추가
new_df['위도'], new_df['경도'] = zip(*new_df['주소'].apply(get_lat_lon))

# 결과를 CSV 파일로 저장
new_df.to_csv('Electric vehicle charging station location_with_coordinates.csv', index=False)

# %%
c
